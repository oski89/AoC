# %%
from itertools import permutations

# %%
with open('input/17.txt','r') as f:
    data = [int(n) for n in f.read().split()]
#data
# Out:
# [43, 3, 4, 10, 21, 44, 4, 6, 47, 41, 34, 17, 17, 44, 36, 31, 46, 9, 27, 38]

# %%
containers = data.copy()
containers.sort(reverse=True)
print(containers)
eggnog = 150
combinations = []

#[combinations.append(perm) for perm in perms if sum(perm) == eggnog]

'''for r in range(3,7):
    perms = list(set(permutations(containers,r)))
    for perm in perms:
        for i in range(1,len(containers)+1):
            if sum(perm[0:i]) == eggnog:
                combinations.append(perm[0:i])'''
print('Part 1:', len(set(combinations)))
# Out:
# [47, 46, 44, 44, 43, 41, 38, 36, 34, 31, 27, 21, 17, 17, 10, 9, 6, 4, 4, 3]
# Part 1: 0

# %%
combinations
# Out:
# [(41, 31, 36, 4, 34, 4),
#  (17, 43, 44, 31, 6, 9),
#  (21, 10, 38, 31, 4, 46),
#  (47, 46, 3, 4, 6, 44),
#  (46, 6, 44, 4, 47, 3),
#  (21, 3, 17, 36, 46, 27),
#  (9, 4, 47, 46, 6, 38),
#  (21, 43, 6, 17, 27, 36),
#  (17, 36, 41, 4, 43, 9),
#  (27, 17, 47, 10, 43, 6),
#  (10, 46, 41, 6, 44, 3),
#  (4, 6, 46, 36, 27, 31),
#  (38, 9, 17, 31, 21, 34),
#  (46, 41, 36, 6, 4, 17),
#  (17, 6, 27, 43, 10, 47),
#  (3, 21, 44, 10, 38, 34),
#  (38, 27, 4, 9, 31, 41),
#  (36, 6, 44, 34, 27, 3),
#  (3, 46, 17, 6, 34, 44),
#  (41, 9, 4, 36, 43, 17),
#  (10, 47, 9, 36, 31, 17),
#  (46, 38, 31, 4, 21, 10),
#  (9, 44, 38, 10, 43, 6),
#  (21, 27, 9, 43, 6, 44),
#  (4, 36, 21, 38, 4, 47),
#  (6, 47, 36, 3, 17, 41),
#  (9, 31, 17, 43, 3, 47),
#  (17, 4, 47, 10, 41, 31),
#  (9, 27, 46, 34, 17, 17),
#  (43, 6, 46, 3, 31, 21),
#  (9, 38, 31, 10, 21, 41),
#  (21, 47, 4, 34, 17, 27),
#  (21, 41, 17, 6, 27, 38),
#  (6, 47, 46, 17, 31, 3),
#  (9, 46, 38, 10, 3, 44),
#  (21, 34, 41, 17, 27, 10),
# ...
